# %% [markdown]
# ## Checking the imported combine files from cluster

# %%
import os
import glob
from pathlib import Path
import pandas as pd

ROOT = Path("/home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine")

REQUIRED_COLS = {
    "date","time","ts_station_k","ts_gldas",
    "lat","lon","elev","cc","lc",
    "land_cover_group","climate_group","temp_class","elevation_class",
    "lat_gldas","lon_gldas",
}

records = []
problems = []

for net_dir in sorted(ROOT.iterdir()):
    if not net_dir.is_dir():
        continue
    network = net_dir.name

    for st_dir in sorted(net_dir.iterdir()):
        if not st_dir.is_dir():
            continue
        station = st_dir.name

        for f in glob.glob(str(st_dir / "*.csv")):
            rec = {"network": network, "station": station, "file": f}
            try:
                df = pd.read_csv(f)
            except Exception as e:
                rec["status"] = "unreadable"
                rec["issue"] = f"read_error: {e}"
                records.append(rec)
                problems.append(rec)
                continue

            rec["status"] = "ok"
            missing = [c for c in REQUIRED_COLS if c not in df.columns]
            if missing:
                rec["status"] = "missing_columns"
                rec["issue"] = "missing: " + ",".join(missing)
                problems.append(rec)

            if df.empty:
                rec["status"] = "empty_file"
                rec["issue"] = "no rows"
                problems.append(rec)
            else:
                n_valid_station = df["ts_station_k"].notna().sum() if "ts_station_k" in df else 0
                n_valid_gldas  = df["ts_gldas"].notna().sum()   if "ts_gldas"  in df else 0
                if n_valid_station == 0 and n_valid_gldas == 0:
                    rec["status"] = "no_valid_ts"
                    rec["issue"] = "ts_station_k & ts_gldas all NaN"
                    problems.append(rec)

            records.append(rec)

df_all = pd.DataFrame(records)

n_networks = df_all["network"].nunique()
n_stations = df_all[["network","station"]].drop_duplicates().shape[0]
n_files    = len(df_all)

print(f"Networks: {n_networks}")
print(f"Stations: {n_stations}")
print(f"Files:    {n_files}")

print("\nProblematic files by status:")
print(df_all["status"].value_counts())

# write reports
df_all.to_csv(ROOT / "audit_gldas_combine_listing.csv", index=False)
if problems:
    pd.DataFrame(problems).to_csv(ROOT / "audit_gldas_combine_problems.csv", index=False)
    print("\nSaved detailed problems to audit_gldas_combine_problems.csv")
else:
    print("\nAll files have required columns and at least one valid ts_station_k or ts_gldas.")
# Out:
# Networks: 44
# Stations: 1362
# Files:    1362
#
# Problematic files by status:
# status
# ok             1307
# no_valid_ts      55
# Name: count, dtype: int64
#
# Saved detailed problems to audit_gldas_combine_problems.csv

# %% [markdown]
# ## Computing SD and correlation for surface layer gldas combine files

# %%
import pandas as pd
from pathlib import Path

# Root dirs
GLDAS_COMBINE_ROOT = Path("/home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine")
OUT_SUMMARY        = Path("/home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/gldas_noah_insitu_sd_corr_summary.csv")

results = []

for network_dir in sorted(GLDAS_COMBINE_ROOT.iterdir()):
    if not network_dir.is_dir():
        continue
    network = network_dir.name

    for station_dir in sorted(network_dir.iterdir()):
        if not station_dir.is_dir():
            continue
        station = station_dir.name

        csv_files = list(station_dir.glob("*.csv"))
        if not csv_files:
            print(f"[WARN] No CSV in {station_dir}, skipping.")
            continue

        csv_path = csv_files[0]

        try:
            df = pd.read_csv(csv_path)
        except Exception as e:
            print(f"[ERROR] Cannot read {csv_path}: {e}")
            results.append({
                "network": network,
                "station": station,
                "n_points": 0,
                "sd_insitu": None,
                "sd_gldas": None,
                "sd_ratio_gldas_insitu": None,
                "corr_gldas_insitu": None,
                "pass_sd_filter": False,
                "pass_corr_filter": False,
            })
            continue

        # Optional: build datetime column
        if "date" in df.columns and "time" in df.columns and "datetime" not in df.columns:
            df["datetime"] = pd.to_datetime(
                df["date"].astype(str) + " " + df["time"].astype(str),
                errors="coerce"
            )

        # Required columns
        if not {"ts_station_k", "ts_gldas"}.issubset(df.columns):
            print(f"[WARN] Missing ts_station_k or ts_gldas in {csv_path}, skipping station.")
            continue

        # Pairwise valid values only
        sub = df[["ts_station_k", "ts_gldas"]].dropna()
        n_points = len(sub)

        if n_points < 2:
            print(f"[WARN] Not enough valid points for {network}/{station} ({n_points}), skipping stats.")
            sd_insitu = sd_gldas = ratio = corr = None
            pass_sd = pass_corr = False
        else:
            sd_insitu = sub["ts_station_k"].std()
            sd_gldas  = sub["ts_gldas"].std()
            ratio = sd_gldas / sd_insitu if sd_insitu and sd_insitu > 0 else None
            corr  = sub["ts_station_k"].corr(sub["ts_gldas"])

            # Filters (same as MERRA2)
            pass_sd   = (ratio is not None) and (0.1 <= ratio <= 3)
            pass_corr = (corr is not None) and (corr >= 0.5)

        results.append({
            "network": network,
            "station": station,
            "n_points": n_points,
            "sd_insitu": sd_insitu,
            "sd_gldas": sd_gldas,
            "sd_ratio_gldas_insitu": ratio,
            "corr_gldas_insitu": corr,
            "pass_sd_filter": pass_sd,
            "pass_corr_filter": pass_corr,
        })

# Build DataFrame
summary_df = pd.DataFrame(results)

# Round numeric columns
num_cols = ["sd_insitu", "sd_gldas", "sd_ratio_gldas_insitu", "corr_gldas_insitu"]
for col in num_cols:
    if col in summary_df.columns:
        summary_df[col] = summary_df[col].round(3)

summary_df.to_csv(OUT_SUMMARY, index=False)
print(f"Saved summary to {OUT_SUMMARY}")
# Out:
# [WARN] Not enough valid points for SCAN/Combate (0), skipping stats.
# [WARN] Not enough valid points for SCAN/MooseInc (0), skipping stats.
# [WARN] Not enough valid points for SCAN/SunleafNursery (0), skipping stats.
# [WARN] Not enough valid points for SCAN/UpperBethlehem (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/BeaverPass (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/Bourne (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/BrownTop (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/CayusePass (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/ClearLake (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/ColumbiaBasin (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/CorduroyFlat (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/DefianceMines (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/GoldAxeCamp (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/HartsPass (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/HighRidge (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/HollandMeadows (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/IndianRock (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/JakesCreek (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/LostHorse (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/MartenRidge (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/MerrittMountain (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/Midas (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/MosesMtn (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/MossSprings (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/Mt.Howard (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/Paradise (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/ParkCreekRidge (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/QuartzMountain (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/RainyPass (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/RockSprings (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/SalmonMeadows (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/SaltCreekFalls (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/SasseRidge (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/SilverCreekNv (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/Silvies (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/SnowMountain (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/SnowstormMtn (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/StagMountain (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/StateLine (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/TaylorButte (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/TentMtnLower (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/Tipton (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/Waterhole (0), skipping stats.
# [WARN] Not enough valid points for SNOTEL/WhiteRiverNv (0), skipping stats.
# [WARN] Not enough valid points for USCRN/Bodega-6-WSW (0), skipping stats.
# [WARN] Not enough valid points for USCRN/Brunswick-23-S (0), skipping stats.
# [WARN] Not enough valid points for USCRN/Coos-Bay-8-SW (0), skipping stats.
# [WARN] Not enough valid points for USCRN/Santa-Barbara-11-W (0), skipping stats.
# [WARN] Not enough valid points for USCRN/Titusville-7-E (0), skipping stats.
# [WARN] Not enough valid points for WSMN/WSMN-1 (0), skipping stats.
# [WARN] Not enough valid points for WSMN/WSMN-2 (0), skipping stats.
# [WARN] Not enough valid points for WSMN/WSMN-3 (0), skipping stats.
# [WARN] Not enough valid points for WSMN/WSMN-4 (0), skipping stats.
# [WARN] Not enough valid points for WSMN/WSMN-5 (0), skipping stats.
# [WARN] Not enough valid points for WSMN/WSMN-6 (0), skipping stats.
# Saved summary to /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/gldas_noah_insitu_sd_corr_summary.csv

# %%
import pandas as pd
from pathlib import Path

summary_path = Path("/home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/gldas_noah_insitu_sd_corr_summary.csv")

df = pd.read_csv(summary_path)

# Total stations
total = len(df)

# Stations that pass both SD and correlation filters
pass_both = df[(df["pass_sd_filter"] == True) & (df["pass_corr_filter"] == True)]

# Stations failing at least one filter
fail_any = df[(df["pass_sd_filter"] == False) | (df["pass_corr_filter"] == False)]

print(f"Total stations          : {total}")
print(f"Pass both (SD & corr)   : {len(pass_both)}")
print(f"Fail SD or corr (or both): {len(fail_any)}")

# Optional: counts per network
print("\nPer network (pass both):")
print(pass_both.groupby("network")["station"].count())

print("\nPer network (fail any):")
print(fail_any.groupby("network")["station"].count())

# NEW: print failing station names per network
print("\nFailing stations by network:")
for network, sub in fail_any.groupby("network"):
    station_list = sorted(sub["station"].unique())
    print(f"{network}: {station_list} = {len(station_list)}")
# Out:
# Total stations          : 1362
# Pass both (SD & corr)   : 1274
# Fail SD or corr (or both): 88
#
# Per network (pass both):
# network
# ARM                    16
# BIEBRZA_S-1            18
# BNZ-LTER               10
# Berlin                  1
# COSMOS-UK              49
# CTP_SMTMN              57
# CW3E                    8
# DAHRA                   1
# FLUXNET-AMERIFLUX       7
# FMI                    25
# FR_Aqui                 5
# HOAL                   31
# HOBE                   30
# HYDROL-NET_PERUGIA      1
# IMA_CAN1               12
# IPE                     1
# LAB-net                 3
# LABFLUX                 1
# MAQU                   21
# MOL-RAO                 2
# MySMNet                 3
# NAQU                   10
# NGARI                  20
# OZNET                  17
# REMEDHUS               20
# RISMA                  23
# ROMPS                   5
# RSMN                   20
# Ru_CFR                  2
# SCAN                  200
# SKKU                    1
# SMN-SDR                33
# SMOSMANIA              22
# SNOTEL                372
# STEMS                   4
# SWEX_POLAND             1
# TAHMO                  23
# TERENO                  5
# TWENTE                 36
# TxSON                  39
# USCRN                 110
# WSMN                    1
# XMS-CAT                 8
# Name: station, dtype: int64
#
# Per network (fail any):
# network
# FMI           2
# HOAL          1
# OZNET         2
# SCAN          9
# SNOTEL       55
# SOILSCAPE     1
# TAHMO         6
# TxSON         1
# USCRN         5
# WSMN          6
# Name: station, dtype: int64
#
# Failing stations by network:
# FMI: ['SOD022', 'SOD023'] = 2
# HOAL: ['Hoal-19'] = 1
# OZNET: ['Alabama', 'Dry-Lake'] = 2
# SCAN: ['Combate', 'Corozal', 'GuilarteForest', 'ManaHouse', 'MaricaoForest', 'MooseInc', 'PuaAkala', 'SunleafNursery', 'UpperBethlehem'] = 9
# SNOTEL: ['AnnieSprings', 'BakerButte', 'BeaverPass', 'Bourne', 'BrownTop', 'CayusePass', 'ClackamasLake', 'ClearLake', 'Coldfoot', 'ColumbiaBasin', 'CorduroyFlat', 'DefianceMines', 'ElkButte', 'FortValley', 'FremontPass', 'GoldAxeCamp', 'GrizzlyPeak', 'HartsPass', 'HighRidge', 'HollandMeadows', 'IndianRock', 'JackWadeJct', 'JackwhackerGulch', 'JakesCreek', 'JonesPass', 'KellyStation', 'LostDog', 'LostHorse', 'MartenRidge', 'MerrittMountain', 'Midas', 'MormonMtnSummit', 'MosesMtn', 'MossSprings', 'Mt.Howard', 'Paradise', 'ParkCreekRidge', 'QuartzMountain', 'RainyPass', 'RockSprings', 'SalmonMeadows', 'SaltCreekFalls', 'SasseRidge', 'SilverCreekNv', 'Silvies', 'SnowMountain', 'SnowstormMtn', 'StagMountain', 'StateLine', 'TaylorButte', 'TentMtnLower', 'Tipton', 'TogwoteePass', 'Waterhole', 'WhiteRiverNv'] = 55
# SOILSCAPE: ['node401'] = 1
# TAHMO: ['ImurtottPrimaryschool', 'MagomanoSecondarySchool', 'MaraTriangleAirstrip', 'MurungaruSecondarySchool', 'NaboishoCamp', 'StJohnsNyamagwa'] = 6
# TxSON: ['CR200-11'] = 1
# USCRN: ['Bodega-6-WSW', 'Brunswick-23-S', 'Coos-Bay-8-SW', 'Santa-Barbara-11-W', 'Titusville-7-E'] = 5
# WSMN: ['WSMN-1', 'WSMN-2', 'WSMN-3', 'WSMN-4', 'WSMN-5', 'WSMN-6'] = 6

# %% [markdown]
# ## Taking pixel mean

# %%
import os
import glob
import pandas as pd
from collections import Counter
from pathlib import Path


# ---------------------------------------------------------------------
# Paths for GLDAS NOAH sub-surface
# ---------------------------------------------------------------------

COMBINE_ROOT = "/home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine"
OUT_ROOT     = "/home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean"
SUMMARY_PATH = "/home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/gldas_noah_insitu_sd_corr_summary.csv"


# ---------------------------------------------------------------------
# Helpers
# ---------------------------------------------------------------------

def majority(series):
    """Most common non-NaN value in a series."""
    vals = [v for v in series if pd.notna(v)]
    if not vals:
        return pd.NA
    return Counter(vals).most_common(1)[0][0]


def classify_elevation(elev):
    """Classify elevation using DEM-I/II/III/IV thresholds."""
    if pd.isna(elev):
        return "DEM-Unknown"
    try:
        elevation = float(elev)
    except Exception:
        return "DEM-Unknown"

    if elevation < 635.523:
        return "DEM-I"
    elif elevation < 1237.128:
        return "DEM-II"
    elif elevation < 1838.733:
        return "DEM-III"
    else:
        return "DEM-IV"


def load_pass_stations(summary_path):
    """
    Read GLDAS summary CSV and return a set of (network, station) pairs
    that passed BOTH SD and correlation filters.
    """
    df = pd.read_csv(summary_path)
    ok = df[(df["pass_sd_filter"] == True) & (df["pass_corr_filter"] == True)]
    return set(zip(ok["network"], ok["station"]))


# ---------------------------------------------------------------------
# Standard processing for moderate-size networks
# ---------------------------------------------------------------------

def process_network(network, pass_stations):
    base_in    = os.path.join(COMBINE_ROOT, network)
    base_out   = os.path.join(OUT_ROOT, network)
    sparse_out = os.path.join(base_out, "sparse")
    dense_out  = os.path.join(base_out, "dense")
    os.makedirs(base_out, exist_ok=True)

    print(f"\n=== Network: {network} ===")
    print(f"Input:  {base_in}")
    print(f"Output: {base_out}")

    station_dirs = sorted(
        d for d in glob.glob(os.path.join(base_in, "*"))
        if os.path.isdir(d)
    )
    n_stations_found = len(station_dirs)
    print(f"Found {n_stations_found} station directories.")

    all_records = []
    used_station_dirs = []

    # Load station data, but only for stations that passed filters
    for station_dir in station_dirs:
        station_name = os.path.basename(station_dir)

        if (network, station_name) not in pass_stations:
            print(f"  Skipping {network}/{station_name} (failed filter in summary).")
            continue

        csv_files = glob.glob(os.path.join(station_dir, "*.csv"))
        if not csv_files:
            continue

        for f in csv_files:
            try:
                df = pd.read_csv(f)
            except Exception as e:
                print(f"  [WARN] Could not read {f}: {e}")
                continue

            # Required columns for GLDAS sub-surface
            required_cols = {
                "date", "time",
                "ts_station_k", "ts_gldas",
                "lat", "lon", "elev",
                "cc", "lc",
                "land_cover_group", "climate_group", "temp_class",
                "elevation_class",
                "lat_gldas", "lon_gldas",
            }
            if not required_cols.issubset(df.columns):
                print(f"  [WARN] Missing required columns in {f}, skipping this file.")
                continue

            df["station"] = station_name
            all_records.append(df)
            used_station_dirs.append(station_dir)

    if not all_records:
        print(f"No valid CSV files found under {base_in}/* (after filtering), skipping.")
        return

    df_all = pd.concat(all_records, ignore_index=True)
    print(f"Loaded {len(set(used_station_dirs))} stations after filtering, total rows: {len(df_all)}")

    # DENSE PIXELS: at least 2 stations in same (lat_gldas, lon_gldas)
    pixel_station_counts = (
        df_all.groupby(["lat_gldas", "lon_gldas"])["station"]
             .nunique()
             .reset_index(name="n_stations")
    )
    dense_pixels = pixel_station_counts.query("n_stations >= 2")[["lat_gldas", "lon_gldas"]]
    print("Total unique pixels:", len(pixel_station_counts))
    print("Dense pixels (n_stations >= 2):", len(dense_pixels))

    n_sparse_files = 0
    n_dense_pixels_processed = 0
    n_dense_files_written = 0

    # DENSE
    print("Processing dense pixels (pixel-mean files)...")
    df_dense_all = df_all.merge(dense_pixels, on=["lat_gldas", "lon_gldas"], how="inner")
    print("Rows in dense pixels (before grouping):", len(df_dense_all))

    stations_in_dense = set()

    # Also read existing dense files to populate stations_in_dense (idempotent)
    if os.path.exists(dense_out):
        existing_dense_files = glob.glob(os.path.join(dense_out, f"{network}_dense_lat*_lon*.csv"))
        for f_dense in existing_dense_files:
            try:
                df_dense_existing = pd.read_csv(f_dense)
                if "stations" in df_dense_existing.columns and not df_dense_existing.empty:
                    for st in str(df_dense_existing["stations"].iloc[0]).split(","):
                        st = st.strip()
                        if st:
                            stations_in_dense.add(st)
            except Exception as e:
                print(f"  [WARN] Could not read existing dense file {f_dense}: {e}")

    if not df_dense_all.empty:
        os.makedirs(dense_out, exist_ok=True)

        for _, pix in dense_pixels.iterrows():
            plat = pix["lat_gldas"]
            plon = pix["lon_gldas"]

            out_dense = os.path.join(
                dense_out,
                f"{network}_dense_lat{plat}_lon{plon}.csv"
            )

            # Skip this pixel if its dense file already exists
            if os.path.exists(out_dense):
                print(f"  Skipping dense pixel lat_gldas={plat}, lon_gldas={plon} (file exists).")
                continue

            df_pix = df_dense_all[
                (df_dense_all["lat_gldas"] == plat) &
                (df_dense_all["lon_gldas"] == plon)
            ].copy()

            if df_pix.empty:
                continue

            print(f"  Dense pixel at lat_gldas={plat}, lon_gldas={plon}, rows={len(df_pix)}")

            group_cols = ["date", "time"]
            station_list = sorted(df_pix["station"].unique())
            stations_str = ",".join(station_list)

            stations_in_dense.update(station_list)

            out_rows = []
            for (date, time), g in df_pix.groupby(group_cols):
                g_valid = g[g["ts_station_k"].notna()]
                n_valid = g_valid["station"].nunique()

                if n_valid >= 2:
                    ts_ref   = g_valid["ts_station_k"].mean()
                    ts_gldas = g_valid["ts_gldas"].iloc[0]

                    lat_val   = majority(g_valid["lat"])
                    lon_val   = majority(g_valid["lon"])
                    cc_val    = majority(g_valid["cc"])
                    lc_val    = majority(g_valid["lc"])
                    lcg_val   = majority(g_valid["land_cover_group"])
                    clim_val  = majority(g_valid["climate_group"])
                    tclass_val = majority(g_valid["temp_class"])

                    elev_mean = g_valid["elev"].mean() if "elev" in g_valid.columns else pd.NA
                    elevc_val = classify_elevation(elev_mean)
                else:
                    ts_ref   = pd.NA
                    ts_gldas = pd.NA
                    lat_val = lon_val = cc_val = lc_val = lcg_val = clim_val = tclass_val = pd.NA
                    elev_mean = pd.NA
                    elevc_val = "DEM-Unknown"

                out_rows.append({
                    "date": date,
                    "time": time,
                    "ts_reference": ts_ref,
                    "ts_gldas": ts_gldas,
                    "lat": lat_val,
                    "lon": lon_val,
                    "cc": cc_val,
                    "lc": lc_val,
                    "land_cover_group": lcg_val,
                    "climate_group": clim_val,
                    "temp_class": tclass_val,
                    "elev": elev_mean,
                    "elevation_class": elevc_val,
                })

            df_pix_mean = pd.DataFrame(out_rows)
            df_pix_mean["ts_reference"] = pd.to_numeric(df_pix_mean["ts_reference"], errors="coerce").round(3)
            df_pix_mean["ts_gldas"]    = pd.to_numeric(df_pix_mean["ts_gldas"],    errors="coerce").round(3)

            df_pix_mean["lat_gldas"] = plat
            df_pix_mean["lon_gldas"] = plon
            df_pix_mean["stations"]  = stations_str

            df_pix_mean.to_csv(out_dense, index=False)
            n_dense_pixels_processed += 1
            n_dense_files_written += 1
            print(f"    Saved dense pixel file: {out_dense}")
    else:
        print("No dense pixels found to process.")

    print(f"Stations that appear in dense pixels: {len(stations_in_dense)}")

    # SPARSE: station-wise files, excluding stations used in any dense pixel
    print("Writing sparse (station-wise) files (excluding dense stations)...")
    for station_dir in station_dirs:
        station_name = os.path.basename(station_dir)

        if (network, station_name) not in pass_stations:
            continue

        if station_name in stations_in_dense:
            continue

        csv_files = glob.glob(os.path.join(station_dir, "*.csv"))
        if not csv_files:
            continue

        if n_sparse_files == 0:
            os.makedirs(sparse_out, exist_ok=True)

        for f in csv_files:
            out_sparse = os.path.join(sparse_out, os.path.basename(f))

            if os.path.exists(out_sparse):
                print(f"  Skipping sparse file for {network}/{station_name} ({out_sparse} exists).")
                continue

            try:
                df = pd.read_csv(f)
            except Exception as e:
                print(f"  [WARN] Could not read {f}: {e}")
                continue

            rename_map = {}
            if "ts_station_k" in df.columns:
                rename_map["ts_station_k"] = "ts_reference"
            df = df.rename(columns=rename_map)

            df.to_csv(out_sparse, index=False)
            n_sparse_files += 1

    print(f"Finished sparse files. Processed {n_sparse_files} station CSV files "
          f"(excluding {len(stations_in_dense)} dense stations).")

    print(f"All done for {network}.")
    print("===== SUMMARY =====")
    print(f"Stations found (raw): {n_stations_found}")
    print(f"Dense pixels processed (with valid data): {n_dense_pixels_processed}")
    print(f"Dense pixel files written: {n_dense_files_written}")


# ---------------------------------------------------------------------
# SNOTEL-specific processing (memory-safe) for GLDAS
# ---------------------------------------------------------------------

def process_network_snotel(pass_stations):
    network = "SNOTEL"
    base_in    = os.path.join(COMBINE_ROOT, network)
    base_out   = os.path.join(OUT_ROOT, network)
    sparse_out = os.path.join(base_out, "sparse")
    dense_out  = os.path.join(base_out, "dense")
    os.makedirs(base_out, exist_ok=True)

    print(f"\n=== Network (chunked): {network} ===")
    print(f"Input:  {base_in}")
    print(f"Output: {base_out}")

    station_dirs = sorted(
        d for d in glob.glob(os.path.join(base_in, "*"))
        if os.path.isdir(d)
    )
    n_stations_found = len(station_dirs)
    print(f"Found {n_stations_found} station directories.")

    # 1) FIRST PASS: determine dense pixels using minimal columns
    pixel_station_pairs = []

    for station_dir in station_dirs:
        station_name = os.path.basename(station_dir)

        if (network, station_name) not in pass_stations:
            continue

        csv_files = glob.glob(os.path.join(station_dir, "*.csv"))
        if not csv_files:
            continue

        for f in csv_files:
            try:
                df = pd.read_csv(f, usecols=["lat_gldas", "lon_gldas"])
            except Exception as e:
                print(f"  [WARN] Could not read minimal cols from {f}: {e}")
                continue

            pix_unique = df.dropna(subset=["lat_gldas", "lon_gldas"]).drop_duplicates()
            for _, row in pix_unique.iterrows():
                pixel_station_pairs.append(
                    (row["lat_gldas"], row["lon_gldas"], station_name)
                )

    if not pixel_station_pairs:
        print("No pixel/station info found for SNOTEL, skipping.")
        return

    df_pix_st = pd.DataFrame(
        pixel_station_pairs,
        columns=["lat_gldas", "lon_gldas", "station"]
    )

    pixel_station_counts = (
        df_pix_st.groupby(["lat_gldas", "lon_gldas"])["station"]
        .nunique()
        .reset_index(name="n_stations")
    )
    dense_pixels = pixel_station_counts.query("n_stations >= 2")[["lat_gldas", "lon_gldas"]]

    print("Total unique pixels:", len(pixel_station_counts))
    print("Dense pixels (n_stations >= 2):", len(dense_pixels))

    stations_in_dense = set()

    # Existing dense files
    if os.path.exists(dense_out):
        existing_dense_files = glob.glob(os.path.join(dense_out, f"{network}_dense_lat*_lon*.csv"))
        for f_dense in existing_dense_files:
            try:
                df_dense_existing = pd.read_csv(f_dense)
                if "stations" in df_dense_existing.columns and not df_dense_existing.empty:
                    for st in str(df_dense_existing["stations"].iloc[0]).split(","):
                        st = st.strip()
                        if st:
                            stations_in_dense.add(st)
            except Exception as e:
                print(f"  [WARN] Could not read existing dense file {f_dense}: {e}")

    n_dense_pixels_processed = 0
    n_dense_files_written = 0

    # 2) SECOND PASS: process each dense pixel separately
    if not dense_pixels.empty:
        os.makedirs(dense_out, exist_ok=True)

        for _, pix in dense_pixels.iterrows():
            plat = pix["lat_gldas"]
            plon = pix["lon_gldas"]

            out_dense = os.path.join(
                dense_out,
                f"{network}_dense_lat{plat}_lon{plon}.csv"
            )

            if os.path.exists(out_dense):
                print(f"  Skipping dense pixel lat_gldas={plat}, lon_gldas={plon} (file exists).")
                continue

            # stations that ever fall into this pixel
            stations_pix = df_pix_st[
                (df_pix_st["lat_gldas"] == plat) &
                (df_pix_st["lon_gldas"] == plon)
            ]["station"].unique()

            df_pix_all = []

            for station_name in stations_pix:
                if (network, station_name) not in pass_stations:
                    continue

                station_dir = os.path.join(base_in, station_name)
                csv_files = glob.glob(os.path.join(station_dir, "*.csv"))
                if not csv_files:
                    continue

                for f in csv_files:
                    try:
                        df = pd.read_csv(f)
                    except Exception as e:
                        print(f"  [WARN] Could not read {f}: {e}")
                        continue

                    required_cols = {
                        "date", "time", "ts_station_k", "ts_gldas",
                        "lat_gldas", "lon_gldas",
                        "lat", "lon",
                        "cc", "lc",
                        "land_cover_group", "climate_group", "temp_class", "elev"
                    }
                    if not required_cols.issubset(df.columns):
                        continue

                    df = df[
                        (df["lat_gldas"] == plat) &
                        (df["lon_gldas"] == plon)
                    ].copy()

                    if df.empty:
                        continue

                    df["station"] = station_name
                    df_pix_all.append(df)

            if not df_pix_all:
                continue

            df_pix = pd.concat(df_pix_all, ignore_index=True)

            print(f"  Dense pixel at lat_gldas={plat}, lon_gldas={plon}, rows={len(df_pix)}")

            group_cols = ["date", "time"]
            station_list = sorted(df_pix["station"].unique())
            stations_str = ",".join(station_list)

            stations_in_dense.update(station_list)

            out_rows = []
            for (date, time), g in df_pix.groupby(group_cols):
                g_valid = g[g["ts_station_k"].notna()]
                n_valid = g_valid["station"].nunique()

                if n_valid >= 2:
                    ts_ref   = g_valid["ts_station_k"].mean()
                    ts_gldas = g_valid["ts_gldas"].iloc[0]

                    lat_val   = majority(g_valid["lat"])
                    lon_val   = majority(g_valid["lon"])
                    cc_val    = majority(g_valid["cc"])
                    lc_val    = majority(g_valid["lc"])
                    lcg_val   = majority(g_valid["land_cover_group"])
                    clim_val  = majority(g_valid["climate_group"])
                    tclass_val = majority(g_valid["temp_class"])

                    elev_mean = g_valid["elev"].mean() if "elev" in g_valid.columns else pd.NA
                    elevc_val = classify_elevation(elev_mean)
                else:
                    ts_ref   = pd.NA
                    ts_gldas = pd.NA
                    lat_val = lon_val = cc_val = lc_val = lcg_val = clim_val = tclass_val = pd.NA
                    elev_mean = pd.NA
                    elevc_val = "DEM-Unknown"

                out_rows.append({
                    "date": date,
                    "time": time,
                    "ts_reference": ts_ref,
                    "ts_gldas": ts_gldas,
                    "lat": lat_val,
                    "lon": lon_val,
                    "cc": cc_val,
                    "lc": lc_val,
                    "land_cover_group": lcg_val,
                    "climate_group": clim_val,
                    "temp_class": tclass_val,
                    "elev": elev_mean,
                    "elevation_class": elevc_val,
                })

            df_pix_mean = pd.DataFrame(out_rows)
            df_pix_mean["ts_reference"] = pd.to_numeric(df_pix_mean["ts_reference"], errors="coerce").round(3)
            df_pix_mean["ts_gldas"]    = pd.to_numeric(df_pix_mean["ts_gldas"],    errors="coerce").round(3)
            df_pix_mean["lat_gldas"] = plat
            df_pix_mean["lon_gldas"] = plon
            df_pix_mean["stations"]  = stations_str

            df_pix_mean.to_csv(out_dense, index=False)
            n_dense_pixels_processed += 1
            n_dense_files_written += 1
            print(f"    Saved dense pixel file: {out_dense}")

    else:
        print("No dense pixels found for SNOTEL.")

    # 3) SPARSE: per-station outputs for stations not in dense pixels
    print(f"Stations that appear in dense pixels: {len(stations_in_dense)}")
    print("Writing sparse (station-wise) files (excluding dense stations)...")

    n_sparse_files = 0

    for station_dir in station_dirs:
        station_name = os.path.basename(station_dir)

        if (network, station_name) not in pass_stations:
            continue
        if station_name in stations_in_dense:
            continue

        csv_files = glob.glob(os.path.join(station_dir, "*.csv"))
        if not csv_files:
            continue

        if n_sparse_files == 0:
            os.makedirs(sparse_out, exist_ok=True)

        for f in csv_files:
            out_sparse = os.path.join(sparse_out, os.path.basename(f))

            if os.path.exists(out_sparse):
                print(f"  Skipping sparse file for {network}/{station_name} ({out_sparse} exists).")
                continue

            try:
                df = pd.read_csv(f)
            except Exception as e:
                print(f"  [WARN] Could not read {f}: {e}")
                continue

            rename_map = {}
            if "ts_station_k" in df.columns:
                rename_map["ts_station_k"] = "ts_reference"
            df = df.rename(columns=rename_map)

            df.to_csv(out_sparse, index=False)
            n_sparse_files += 1

    print(f"Finished sparse files. Processed {n_sparse_files} station CSV files "
          f"(excluding {len(stations_in_dense)} dense stations).")

    print(f"All done for {network}.")
    print("===== SUMMARY =====")
    print(f"Dense pixels processed (with valid data): {n_dense_pixels_processed}")
    print(f"Dense pixel files written: {n_dense_files_written}")


# ---------------------------------------------------------------------
# Main
# ---------------------------------------------------------------------

if __name__ == "__main__":
    pass_stations = load_pass_stations(SUMMARY_PATH)

    network_dirs = sorted(
        d for d in glob.glob(os.path.join(COMBINE_ROOT, "*"))
        if os.path.isdir(d)
    )
    networks = [os.path.basename(d) for d in network_dirs]

    print("Networks found:", networks)
    for net in networks:
        if net == "SNOTEL":
            process_network_snotel(pass_stations)
        else:
            process_network(net, pass_stations)
# Out:
# Networks found: ['ARM', 'BIEBRZA_S-1', 'BNZ-LTER', 'Berlin', 'COSMOS-UK', 'CTP_SMTMN', 'CW3E', 'DAHRA', 'FLUXNET-AMERIFLUX', 'FMI', 'FR_Aqui', 'HOAL', 'HOBE', 'HYDROL-NET_PERUGIA', 'IMA_CAN1', 'IPE', 'LAB-net', 'LABFLUX', 'MAQU', 'MOL-RAO', 'MySMNet', 'NAQU', 'NGARI', 'OZNET', 'REMEDHUS', 'RISMA', 'ROMPS', 'RSMN', 'Ru_CFR', 'SCAN', 'SKKU', 'SMN-SDR', 'SMOSMANIA', 'SNOTEL', 'SOILSCAPE', 'STEMS', 'SWEX_POLAND', 'TAHMO', 'TERENO', 'TWENTE', 'TxSON', 'USCRN', 'WSMN', 'XMS-CAT']
#
# === Network: ARM ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/ARM
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/ARM
# Found 16 station directories.
# Loaded 16 stations after filtering, total rows: 330658
# Total unique pixels: 16
# Dense pixels (n_stations >= 2): 0
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 0
# No dense pixels found to process.
# Stations that appear in dense pixels: 0
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 16 station CSV files (excluding 0 dense stations).
# All done for ARM.
# ===== SUMMARY =====
# Stations found (raw): 16
# Dense pixels processed (with valid data): 0
# Dense pixel files written: 0
#
# === Network: BIEBRZA_S-1 ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/BIEBRZA_S-1
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/BIEBRZA_S-1
# Found 18 station directories.
# Loaded 18 stations after filtering, total rows: 175637
# Total unique pixels: 1
# Dense pixels (n_stations >= 2): 1
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 175637
#   Dense pixel at lat_gldas=53.625, lon_gldas=22.875, rows=175637
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/BIEBRZA_S-1/dense/BIEBRZA_S-1_dense_lat53.625_lon22.875.csv
# Stations that appear in dense pixels: 18
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 0 station CSV files (excluding 18 dense stations).
# All done for BIEBRZA_S-1.
# ===== SUMMARY =====
# Stations found (raw): 18
# Dense pixels processed (with valid data): 1
# Dense pixel files written: 1
#
# === Network: BNZ-LTER ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/BNZ-LTER
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/BNZ-LTER
# Found 10 station directories.
# Loaded 10 stations after filtering, total rows: 29290
# Total unique pixels: 3
# Dense pixels (n_stations >= 2): 2
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 26361
#   Dense pixel at lat_gldas=64.625, lon_gldas=-148.375, rows=17574
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/BNZ-LTER/dense/BNZ-LTER_dense_lat64.625_lon-148.375.csv
#   Dense pixel at lat_gldas=64.625, lon_gldas=-148.125, rows=8787
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/BNZ-LTER/dense/BNZ-LTER_dense_lat64.625_lon-148.125.csv
# Stations that appear in dense pixels: 9
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 1 station CSV files (excluding 9 dense stations).
# All done for BNZ-LTER.
# ===== SUMMARY =====
# Stations found (raw): 10
# Dense pixels processed (with valid data): 2
# Dense pixel files written: 2
#
# === Network: Berlin ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/Berlin
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/Berlin
# Found 1 station directories.
# Loaded 1 stations after filtering, total rows: 3397
# Total unique pixels: 1
# Dense pixels (n_stations >= 2): 0
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 0
# No dense pixels found to process.
# Stations that appear in dense pixels: 0
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 1 station CSV files (excluding 0 dense stations).
# All done for Berlin.
# ===== SUMMARY =====
# Stations found (raw): 1
# Dense pixels processed (with valid data): 0
# Dense pixel files written: 0
#
# === Network: COSMOS-UK ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/COSMOS-UK
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/COSMOS-UK
# Found 49 station directories.
# Loaded 49 stations after filtering, total rows: 732401
# Total unique pixels: 48
# Dense pixels (n_stations >= 2): 1
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 42148
#   Dense pixel at lat_gldas=51.625, lon_gldas=-1.375, rows=42148
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/COSMOS-UK/dense/COSMOS-UK_dense_lat51.625_lon-1.375.csv
# Stations that appear in dense pixels: 2
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 47 station CSV files (excluding 2 dense stations).
# All done for COSMOS-UK.
# ===== SUMMARY =====
# Stations found (raw): 49
# Dense pixels processed (with valid data): 1
# Dense pixel files written: 1
#
# === Network: CTP_SMTMN ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/CTP_SMTMN
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/CTP_SMTMN
# Found 57 station directories.
# Loaded 57 stations after filtering, total rows: 751362
# Total unique pixels: 12
# Dense pixels (n_stations >= 2): 11
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 737578
#   Dense pixel at lat_gldas=31.125, lon_gldas=91.625, rows=41352
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/CTP_SMTMN/dense/CTP_SMTMN_dense_lat31.125_lon91.625.csv
#   Dense pixel at lat_gldas=31.125, lon_gldas=92.125, rows=27568
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/CTP_SMTMN/dense/CTP_SMTMN_dense_lat31.125_lon92.125.csv
#   Dense pixel at lat_gldas=31.125, lon_gldas=92.375, rows=41352
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/CTP_SMTMN/dense/CTP_SMTMN_dense_lat31.125_lon92.375.csv
#   Dense pixel at lat_gldas=31.375, lon_gldas=91.875, rows=66633
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/CTP_SMTMN/dense/CTP_SMTMN_dense_lat31.375_lon91.875.csv
#   Dense pixel at lat_gldas=31.375, lon_gldas=92.125, rows=55133
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/CTP_SMTMN/dense/CTP_SMTMN_dense_lat31.375_lon92.125.csv
#   Dense pixel at lat_gldas=31.625, lon_gldas=91.625, rows=35555
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/CTP_SMTMN/dense/CTP_SMTMN_dense_lat31.625_lon91.625.csv
#   Dense pixel at lat_gldas=31.625, lon_gldas=91.875, rows=282680
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/CTP_SMTMN/dense/CTP_SMTMN_dense_lat31.625_lon91.875.csv
#   Dense pixel at lat_gldas=31.625, lon_gldas=92.125, rows=38428
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/CTP_SMTMN/dense/CTP_SMTMN_dense_lat31.625_lon92.125.csv
#   Dense pixel at lat_gldas=31.625, lon_gldas=92.375, rows=38605
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/CTP_SMTMN/dense/CTP_SMTMN_dense_lat31.625_lon92.375.csv
#   Dense pixel at lat_gldas=31.875, lon_gldas=91.625, rows=55136
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/CTP_SMTMN/dense/CTP_SMTMN_dense_lat31.875_lon91.625.csv
#   Dense pixel at lat_gldas=31.875, lon_gldas=91.875, rows=55136
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/CTP_SMTMN/dense/CTP_SMTMN_dense_lat31.875_lon91.875.csv
# Stations that appear in dense pixels: 56
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 1 station CSV files (excluding 56 dense stations).
# All done for CTP_SMTMN.
# ===== SUMMARY =====
# Stations found (raw): 57
# Dense pixels processed (with valid data): 11
# Dense pixel files written: 11
#
# === Network: CW3E ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/CW3E
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/CW3E
# Found 8 station directories.
# Loaded 8 stations after filtering, total rows: 64696
# Total unique pixels: 4
# Dense pixels (n_stations >= 2): 2
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 58015
#   Dense pixel at lat_gldas=39.125, lon_gldas=-123.125, rows=29254
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/CW3E/dense/CW3E_dense_lat39.125_lon-123.125.csv
#   Dense pixel at lat_gldas=39.375, lon_gldas=-123.125, rows=28761
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/CW3E/dense/CW3E_dense_lat39.375_lon-123.125.csv
# Stations that appear in dense pixels: 6
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 2 station CSV files (excluding 6 dense stations).
# All done for CW3E.
# ===== SUMMARY =====
# Stations found (raw): 8
# Dense pixels processed (with valid data): 2
# Dense pixel files written: 2
#
# === Network: DAHRA ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/DAHRA
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/DAHRA
# Found 1 station directories.
# Loaded 1 stations after filtering, total rows: 11689
# Total unique pixels: 1
# Dense pixels (n_stations >= 2): 0
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 0
# No dense pixels found to process.
# Stations that appear in dense pixels: 0
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 1 station CSV files (excluding 0 dense stations).
# All done for DAHRA.
# ===== SUMMARY =====
# Stations found (raw): 1
# Dense pixels processed (with valid data): 0
# Dense pixel files written: 0
#
# === Network: FLUXNET-AMERIFLUX ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/FLUXNET-AMERIFLUX
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/FLUXNET-AMERIFLUX
# Found 7 station directories.
# Loaded 7 stations after filtering, total rows: 97108
# Total unique pixels: 4
# Dense pixels (n_stations >= 2): 2
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 78460
#   Dense pixel at lat_gldas=38.125, lon_gldas=-121.625, rows=31052
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/FLUXNET-AMERIFLUX/dense/FLUXNET-AMERIFLUX_dense_lat38.125_lon-121.625.csv
#   Dense pixel at lat_gldas=38.375, lon_gldas=-120.875, rows=47408
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/FLUXNET-AMERIFLUX/dense/FLUXNET-AMERIFLUX_dense_lat38.375_lon-120.875.csv
# Stations that appear in dense pixels: 5
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 2 station CSV files (excluding 5 dense stations).
# All done for FLUXNET-AMERIFLUX.
# ===== SUMMARY =====
# Stations found (raw): 7
# Dense pixels processed (with valid data): 2
# Dense pixel files written: 2
#
# === Network: FMI ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/FMI
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/FMI
# Found 27 station directories.
#   Skipping FMI/SOD022 (failed filter in summary).
#   Skipping FMI/SOD023 (failed filter in summary).
# Loaded 25 stations after filtering, total rows: 549550
# Total unique pixels: 3
# Dense pixels (n_stations >= 2): 2
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 531339
#   Dense pixel at lat_gldas=67.375, lon_gldas=26.625, rows=468324
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/FMI/dense/FMI_dense_lat67.375_lon26.625.csv
#   Dense pixel at lat_gldas=68.375, lon_gldas=27.625, rows=63015
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/FMI/dense/FMI_dense_lat68.375_lon27.625.csv
# Stations that appear in dense pixels: 24
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 1 station CSV files (excluding 24 dense stations).
# All done for FMI.
# ===== SUMMARY =====
# Stations found (raw): 27
# Dense pixels processed (with valid data): 2
# Dense pixel files written: 2
#
# === Network: FR_Aqui ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/FR_Aqui
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/FR_Aqui
# Found 5 station directories.
# Loaded 5 stations after filtering, total rows: 89866
# Total unique pixels: 3
# Dense pixels (n_stations >= 2): 1
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 42016
#   Dense pixel at lat_gldas=44.375, lon_gldas=-0.875, rows=42016
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/FR_Aqui/dense/FR_Aqui_dense_lat44.375_lon-0.875.csv
# Stations that appear in dense pixels: 3
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 2 station CSV files (excluding 3 dense stations).
# All done for FR_Aqui.
# ===== SUMMARY =====
# Stations found (raw): 5
# Dense pixels processed (with valid data): 1
# Dense pixel files written: 1
#
# === Network: HOAL ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/HOAL
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/HOAL
# Found 32 station directories.
#   Skipping HOAL/Hoal-19 (failed filter in summary).
# Loaded 31 stations after filtering, total rows: 601379
# Total unique pixels: 1
# Dense pixels (n_stations >= 2): 1
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 601379
#   Dense pixel at lat_gldas=48.125, lon_gldas=15.125, rows=601379
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/HOAL/dense/HOAL_dense_lat48.125_lon15.125.csv
# Stations that appear in dense pixels: 31
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 0 station CSV files (excluding 31 dense stations).
# All done for HOAL.
# ===== SUMMARY =====
# Stations found (raw): 32
# Dense pixels processed (with valid data): 1
# Dense pixel files written: 1
#
# === Network: HOBE ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/HOBE
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/HOBE
# Found 30 station directories.
# Loaded 30 stations after filtering, total rows: 586549
# Total unique pixels: 5
# Dense pixels (n_stations >= 2): 4
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 568048
#   Dense pixel at lat_gldas=55.875, lon_gldas=8.875, rows=121519
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/HOBE/dense/HOBE_dense_lat55.875_lon8.875.csv
#   Dense pixel at lat_gldas=55.875, lon_gldas=9.125, rows=231018
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/HOBE/dense/HOBE_dense_lat55.875_lon9.125.csv
#   Dense pixel at lat_gldas=55.875, lon_gldas=9.375, rows=41734
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/HOBE/dense/HOBE_dense_lat55.875_lon9.375.csv
#   Dense pixel at lat_gldas=56.125, lon_gldas=9.125, rows=173777
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/HOBE/dense/HOBE_dense_lat56.125_lon9.125.csv
# Stations that appear in dense pixels: 29
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 1 station CSV files (excluding 29 dense stations).
# All done for HOBE.
# ===== SUMMARY =====
# Stations found (raw): 30
# Dense pixels processed (with valid data): 4
# Dense pixel files written: 4
#
# === Network: HYDROL-NET_PERUGIA ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/HYDROL-NET_PERUGIA
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/HYDROL-NET_PERUGIA
# Found 1 station directories.
# Loaded 1 stations after filtering, total rows: 14454
# Total unique pixels: 1
# Dense pixels (n_stations >= 2): 0
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 0
# No dense pixels found to process.
# Stations that appear in dense pixels: 0
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 1 station CSV files (excluding 0 dense stations).
# All done for HYDROL-NET_PERUGIA.
# ===== SUMMARY =====
# Stations found (raw): 1
# Dense pixels processed (with valid data): 0
# Dense pixel files written: 0
#
# === Network: IMA_CAN1 ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/IMA_CAN1
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/IMA_CAN1
# Found 12 station directories.
# Loaded 12 stations after filtering, total rows: 131849
# Total unique pixels: 1
# Dense pixels (n_stations >= 2): 1
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 131849
#   Dense pixel at lat_gldas=44.625, lon_gldas=8.625, rows=131849
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/IMA_CAN1/dense/IMA_CAN1_dense_lat44.625_lon8.625.csv
# Stations that appear in dense pixels: 12
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 0 station CSV files (excluding 12 dense stations).
# All done for IMA_CAN1.
# ===== SUMMARY =====
# Stations found (raw): 12
# Dense pixels processed (with valid data): 1
# Dense pixel files written: 1
#
# === Network: IPE ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/IPE
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/IPE
# Found 1 station directories.
# Loaded 1 stations after filtering, total rows: 8210
# Total unique pixels: 1
# Dense pixels (n_stations >= 2): 0
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 0
# No dense pixels found to process.
# Stations that appear in dense pixels: 0
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 1 station CSV files (excluding 0 dense stations).
# All done for IPE.
# ===== SUMMARY =====
# Stations found (raw): 1
# Dense pixels processed (with valid data): 0
# Dense pixel files written: 0
#
# === Network: LAB-net ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/LAB-net
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/LAB-net
# Found 3 station directories.
# Loaded 3 stations after filtering, total rows: 44151
# Total unique pixels: 3
# Dense pixels (n_stations >= 2): 0
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 0
# No dense pixels found to process.
# Stations that appear in dense pixels: 0
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 3 station CSV files (excluding 0 dense stations).
# All done for LAB-net.
# ===== SUMMARY =====
# Stations found (raw): 3
# Dense pixels processed (with valid data): 0
# Dense pixel files written: 0
#
# === Network: LABFLUX ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/LABFLUX
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/LABFLUX
# Found 1 station directories.
# Loaded 1 stations after filtering, total rows: 5812
# Total unique pixels: 1
# Dense pixels (n_stations >= 2): 0
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 0
# No dense pixels found to process.
# Stations that appear in dense pixels: 0
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 1 station CSV files (excluding 0 dense stations).
# All done for LABFLUX.
# ===== SUMMARY =====
# Stations found (raw): 1
# Dense pixels processed (with valid data): 0
# Dense pixel files written: 0
#
# === Network: MAQU ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/MAQU
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/MAQU
# Found 21 station directories.
# Loaded 21 stations after filtering, total rows: 306624
# Total unique pixels: 10
# Dense pixels (n_stations >= 2): 5
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 211573
#   Dense pixel at lat_gldas=33.625, lon_gldas=101.875, rows=30536
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/MAQU/dense/MAQU_dense_lat33.625_lon101.875.csv
#   Dense pixel at lat_gldas=33.625, lon_gldas=102.125, rows=26771
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/MAQU/dense/MAQU_dense_lat33.625_lon102.125.csv
#   Dense pixel at lat_gldas=33.875, lon_gldas=102.125, rows=67090
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/MAQU/dense/MAQU_dense_lat33.875_lon102.125.csv
#   Dense pixel at lat_gldas=33.875, lon_gldas=102.625, rows=63479
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/MAQU/dense/MAQU_dense_lat33.875_lon102.625.csv
#   Dense pixel at lat_gldas=34.125, lon_gldas=101.875, rows=23697
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/MAQU/dense/MAQU_dense_lat34.125_lon101.875.csv
# Stations that appear in dense pixels: 16
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 5 station CSV files (excluding 16 dense stations).
# All done for MAQU.
# ===== SUMMARY =====
# Stations found (raw): 21
# Dense pixels processed (with valid data): 5
# Dense pixel files written: 5
#
# === Network: MOL-RAO ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/MOL-RAO
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/MOL-RAO
# Found 2 station directories.
# Loaded 2 stations after filtering, total rows: 38569
# Total unique pixels: 2
# Dense pixels (n_stations >= 2): 0
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 0
# No dense pixels found to process.
# Stations that appear in dense pixels: 0
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 2 station CSV files (excluding 0 dense stations).
# All done for MOL-RAO.
# ===== SUMMARY =====
# Stations found (raw): 2
# Dense pixels processed (with valid data): 0
# Dense pixel files written: 0
#
# === Network: MySMNet ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/MySMNet
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/MySMNet
# Found 3 station directories.
# Loaded 3 stations after filtering, total rows: 13896
# Total unique pixels: 1
# Dense pixels (n_stations >= 2): 1
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 13896
#   Dense pixel at lat_gldas=1.875, lon_gldas=103.375, rows=13896
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/MySMNet/dense/MySMNet_dense_lat1.875_lon103.375.csv
# Stations that appear in dense pixels: 3
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 0 station CSV files (excluding 3 dense stations).
# All done for MySMNet.
# ===== SUMMARY =====
# Stations found (raw): 3
# Dense pixels processed (with valid data): 1
# Dense pixel files written: 1
#
# === Network: NAQU ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/NAQU
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/NAQU
# Found 10 station directories.
# Loaded 10 stations after filtering, total rows: 141587
# Total unique pixels: 3
# Dense pixels (n_stations >= 2): 1
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 104948
#   Dense pixel at lat_gldas=31.375, lon_gldas=91.875, rows=104948
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/NAQU/dense/NAQU_dense_lat31.375_lon91.875.csv
# Stations that appear in dense pixels: 8
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 2 station CSV files (excluding 8 dense stations).
# All done for NAQU.
# ===== SUMMARY =====
# Stations found (raw): 10
# Dense pixels processed (with valid data): 1
# Dense pixel files written: 1
#
# === Network: NGARI ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/NGARI
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/NGARI
# Found 20 station directories.
# Loaded 20 stations after filtering, total rows: 315605
# Total unique pixels: 5
# Dense pixels (n_stations >= 2): 4
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 293140
#   Dense pixel at lat_gldas=32.375, lon_gldas=80.125, rows=76858
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/NGARI/dense/NGARI_dense_lat32.375_lon80.125.csv
#   Dense pixel at lat_gldas=32.625, lon_gldas=79.875, rows=114646
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/NGARI/dense/NGARI_dense_lat32.625_lon79.875.csv
#   Dense pixel at lat_gldas=32.625, lon_gldas=80.125, rows=46330
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/NGARI/dense/NGARI_dense_lat32.625_lon80.125.csv
#   Dense pixel at lat_gldas=33.375, lon_gldas=79.625, rows=55306
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/NGARI/dense/NGARI_dense_lat33.375_lon79.625.csv
# Stations that appear in dense pixels: 19
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 1 station CSV files (excluding 19 dense stations).
# All done for NGARI.
# ===== SUMMARY =====
# Stations found (raw): 20
# Dense pixels processed (with valid data): 4
# Dense pixel files written: 4
#
# === Network: OZNET ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/OZNET
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/OZNET
# Found 19 station directories.
#   Skipping OZNET/Alabama (failed filter in summary).
#   Skipping OZNET/Dry-Lake (failed filter in summary).
# Loaded 17 stations after filtering, total rows: 366834
# Total unique pixels: 12
# Dense pixels (n_stations >= 2): 5
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 217811
#   Dense pixel at lat_gldas=-35.375, lon_gldas=147.375, rows=42237
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/OZNET/dense/OZNET_dense_lat-35.375_lon147.375.csv
#   Dense pixel at lat_gldas=-35.125, lon_gldas=146.375, rows=52543
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/OZNET/dense/OZNET_dense_lat-35.125_lon146.375.csv
#   Dense pixel at lat_gldas=-35.125, lon_gldas=147.375, rows=30712
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/OZNET/dense/OZNET_dense_lat-35.125_lon147.375.csv
#   Dense pixel at lat_gldas=-34.875, lon_gldas=146.125, rows=52574
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/OZNET/dense/OZNET_dense_lat-34.875_lon146.125.csv
#   Dense pixel at lat_gldas=-34.625, lon_gldas=146.125, rows=39745
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/OZNET/dense/OZNET_dense_lat-34.625_lon146.125.csv
# Stations that appear in dense pixels: 10
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 7 station CSV files (excluding 10 dense stations).
# All done for OZNET.
# ===== SUMMARY =====
# Stations found (raw): 19
# Dense pixels processed (with valid data): 5
# Dense pixel files written: 5
#
# === Network: REMEDHUS ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/REMEDHUS
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/REMEDHUS
# Found 20 station directories.
# Loaded 20 stations after filtering, total rows: 516450
# Total unique pixels: 5
# Dense pixels (n_stations >= 2): 4
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 490295
#   Dense pixel at lat_gldas=41.125, lon_gldas=-5.375, rows=96133
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/REMEDHUS/dense/REMEDHUS_dense_lat41.125_lon-5.375.csv
#   Dense pixel at lat_gldas=41.375, lon_gldas=-5.625, rows=52574
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/REMEDHUS/dense/REMEDHUS_dense_lat41.375_lon-5.625.csv
#   Dense pixel at lat_gldas=41.375, lon_gldas=-5.375, rows=289014
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/REMEDHUS/dense/REMEDHUS_dense_lat41.375_lon-5.375.csv
#   Dense pixel at lat_gldas=41.375, lon_gldas=-5.125, rows=52574
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/REMEDHUS/dense/REMEDHUS_dense_lat41.375_lon-5.125.csv
# Stations that appear in dense pixels: 19
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 1 station CSV files (excluding 19 dense stations).
# All done for REMEDHUS.
# ===== SUMMARY =====
# Stations found (raw): 20
# Dense pixels processed (with valid data): 4
# Dense pixel files written: 4
#
# === Network: RISMA ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/RISMA
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/RISMA
# Found 23 station directories.
# Loaded 23 stations after filtering, total rows: 416370
# Total unique pixels: 12
# Dense pixels (n_stations >= 2): 7
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 340499
#   Dense pixel at lat_gldas=45.375, lon_gldas=-75.125, rows=39251
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/RISMA/dense/RISMA_dense_lat45.375_lon-75.125.csv
#   Dense pixel at lat_gldas=45.375, lon_gldas=-74.875, rows=51063
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/RISMA/dense/RISMA_dense_lat45.375_lon-74.875.csv
#   Dense pixel at lat_gldas=49.625, lon_gldas=-98.125, rows=57774
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/RISMA/dense/RISMA_dense_lat49.625_lon-98.125.csv
#   Dense pixel at lat_gldas=49.625, lon_gldas=-97.875, rows=79168
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/RISMA/dense/RISMA_dense_lat49.625_lon-97.875.csv
#   Dense pixel at lat_gldas=50.125, lon_gldas=-97.625, rows=34075
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/RISMA/dense/RISMA_dense_lat50.125_lon-97.625.csv
#   Dense pixel at lat_gldas=51.375, lon_gldas=-106.625, rows=39584
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/RISMA/dense/RISMA_dense_lat51.375_lon-106.625.csv
#   Dense pixel at lat_gldas=51.375, lon_gldas=-106.375, rows=39584
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/RISMA/dense/RISMA_dense_lat51.375_lon-106.375.csv
# Stations that appear in dense pixels: 18
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 5 station CSV files (excluding 18 dense stations).
# All done for RISMA.
# ===== SUMMARY =====
# Stations found (raw): 23
# Dense pixels processed (with valid data): 7
# Dense pixel files written: 7
#
# === Network: ROMPS ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/ROMPS
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/ROMPS
# Found 5 station directories.
# Loaded 5 stations after filtering, total rows: 121121
# Total unique pixels: 5
# Dense pixels (n_stations >= 2): 0
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 0
# No dense pixels found to process.
# Stations that appear in dense pixels: 0
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 5 station CSV files (excluding 0 dense stations).
# All done for ROMPS.
# ===== SUMMARY =====
# Stations found (raw): 5
# Dense pixels processed (with valid data): 0
# Dense pixel files written: 0
#
# === Network: RSMN ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/RSMN
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/RSMN
# Found 20 station directories.
# Loaded 20 stations after filtering, total rows: 340078
# Total unique pixels: 20
# Dense pixels (n_stations >= 2): 0
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 0
# No dense pixels found to process.
# Stations that appear in dense pixels: 0
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 20 station CSV files (excluding 0 dense stations).
# All done for RSMN.
# ===== SUMMARY =====
# Stations found (raw): 20
# Dense pixels processed (with valid data): 0
# Dense pixel files written: 0
#
# === Network: Ru_CFR ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/Ru_CFR
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/Ru_CFR
# Found 2 station directories.
# Loaded 2 stations after filtering, total rows: 32421
# Total unique pixels: 1
# Dense pixels (n_stations >= 2): 1
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 32421
#   Dense pixel at lat_gldas=56.375, lon_gldas=32.875, rows=32421
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/Ru_CFR/dense/Ru_CFR_dense_lat56.375_lon32.875.csv
# Stations that appear in dense pixels: 2
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 0 station CSV files (excluding 2 dense stations).
# All done for Ru_CFR.
# ===== SUMMARY =====
# Stations found (raw): 2
# Dense pixels processed (with valid data): 1
# Dense pixel files written: 1
#
# === Network: SCAN ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/SCAN
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SCAN
# Found 209 station directories.
#   Skipping SCAN/Combate (failed filter in summary).
#   Skipping SCAN/Corozal (failed filter in summary).
#   Skipping SCAN/GuilarteForest (failed filter in summary).
#   Skipping SCAN/ManaHouse (failed filter in summary).
#   Skipping SCAN/MaricaoForest (failed filter in summary).
#   Skipping SCAN/MooseInc (failed filter in summary).
#   Skipping SCAN/PuaAkala (failed filter in summary).
#   Skipping SCAN/SunleafNursery (failed filter in summary).
#   Skipping SCAN/UpperBethlehem (failed filter in summary).
# Loaded 200 stations after filtering, total rows: 4743383
# Total unique pixels: 194
# Dense pixels (n_stations >= 2): 5
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 244435
#   Dense pixel at lat_gldas=20.125, lon_gldas=-155.625, rows=51839
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SCAN/dense/SCAN_dense_lat20.125_lon-155.625.csv
#   Dense pixel at lat_gldas=34.875, lon_gldas=-86.625, rows=77059
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SCAN/dense/SCAN_dense_lat34.875_lon-86.625.csv
#   Dense pixel at lat_gldas=36.375, lon_gldas=-115.875, rows=52574
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SCAN/dense/SCAN_dense_lat36.375_lon-115.875.csv
#   Dense pixel at lat_gldas=38.625, lon_gldas=-92.125, rows=15358
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SCAN/dense/SCAN_dense_lat38.625_lon-92.125.csv
#   Dense pixel at lat_gldas=40.875, lon_gldas=-104.625, rows=47605
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SCAN/dense/SCAN_dense_lat40.875_lon-104.625.csv
# Stations that appear in dense pixels: 11
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 189 station CSV files (excluding 11 dense stations).
# All done for SCAN.
# ===== SUMMARY =====
# Stations found (raw): 209
# Dense pixels processed (with valid data): 5
# Dense pixel files written: 5
#
# === Network: SKKU ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/SKKU
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SKKU
# Found 1 station directories.
# Loaded 1 stations after filtering, total rows: 6559
# Total unique pixels: 1
# Dense pixels (n_stations >= 2): 0
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 0
# No dense pixels found to process.
# Stations that appear in dense pixels: 0
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 1 station CSV files (excluding 0 dense stations).
# All done for SKKU.
# ===== SUMMARY =====
# Stations found (raw): 1
# Dense pixels processed (with valid data): 0
# Dense pixel files written: 0
#
# === Network: SMN-SDR ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/SMN-SDR
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SMN-SDR
# Found 33 station directories.
# Loaded 33 stations after filtering, total rows: 126518
# Total unique pixels: 15
# Dense pixels (n_stations >= 2): 6
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 91936
#   Dense pixel at lat_gldas=41.875, lon_gldas=116.375, rows=7630
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SMN-SDR/dense/SMN-SDR_dense_lat41.875_lon116.375.csv
#   Dense pixel at lat_gldas=42.125, lon_gldas=115.875, rows=41954
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SMN-SDR/dense/SMN-SDR_dense_lat42.125_lon115.875.csv
#   Dense pixel at lat_gldas=42.125, lon_gldas=116.125, rows=16494
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SMN-SDR/dense/SMN-SDR_dense_lat42.125_lon116.125.csv
#   Dense pixel at lat_gldas=42.375, lon_gldas=115.625, rows=7019
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SMN-SDR/dense/SMN-SDR_dense_lat42.375_lon115.625.csv
#   Dense pixel at lat_gldas=42.375, lon_gldas=115.875, rows=7028
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SMN-SDR/dense/SMN-SDR_dense_lat42.375_lon115.875.csv
#   Dense pixel at lat_gldas=42.375, lon_gldas=116.125, rows=11811
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SMN-SDR/dense/SMN-SDR_dense_lat42.375_lon116.125.csv
# Stations that appear in dense pixels: 24
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 9 station CSV files (excluding 24 dense stations).
# All done for SMN-SDR.
# ===== SUMMARY =====
# Stations found (raw): 33
# Dense pixels processed (with valid data): 6
# Dense pixel files written: 6
#
# === Network: SMOSMANIA ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/SMOSMANIA
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SMOSMANIA
# Found 22 station directories.
# Loaded 22 stations after filtering, total rows: 550074
# Total unique pixels: 19
# Dense pixels (n_stations >= 2): 2
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 105148
#   Dense pixel at lat_gldas=43.375, lon_gldas=3.375, rows=52574
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SMOSMANIA/dense/SMOSMANIA_dense_lat43.375_lon3.375.csv
#   Dense pixel at lat_gldas=44.625, lon_gldas=4.125, rows=52574
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SMOSMANIA/dense/SMOSMANIA_dense_lat44.625_lon4.125.csv
# Stations that appear in dense pixels: 5
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 17 station CSV files (excluding 5 dense stations).
# All done for SMOSMANIA.
# ===== SUMMARY =====
# Stations found (raw): 22
# Dense pixels processed (with valid data): 2
# Dense pixel files written: 2
#
# === Network (chunked): SNOTEL ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/SNOTEL
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL
# Found 427 station directories.
# Total unique pixels: 265
# Dense pixels (n_stations >= 2): 64
#   Dense pixel at lat_gldas=34.875, lon_gldas=-111.625, rows=45737
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat34.875_lon-111.625.csv
#   Dense pixel at lat_gldas=36.125, lon_gldas=-106.875, rows=49007
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat36.125_lon-106.875.csv
#   Dense pixel at lat_gldas=36.125, lon_gldas=-105.625, rows=69457
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat36.125_lon-105.625.csv
#   Dense pixel at lat_gldas=36.375, lon_gldas=-115.625, rows=52574
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat36.375_lon-115.625.csv
#   Dense pixel at lat_gldas=36.625, lon_gldas=-105.375, rows=51565
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat36.625_lon-105.375.csv
#   Dense pixel at lat_gldas=37.125, lon_gldas=-105.125, rows=52574
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat37.125_lon-105.125.csv
#   Dense pixel at lat_gldas=37.375, lon_gldas=-113.875, rows=52574
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat37.375_lon-113.875.csv
#   Dense pixel at lat_gldas=37.375, lon_gldas=-112.625, rows=47159
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat37.375_lon-112.625.csv
#   Dense pixel at lat_gldas=37.375, lon_gldas=-106.875, rows=52574
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat37.375_lon-106.875.csv
#   Dense pixel at lat_gldas=37.625, lon_gldas=-112.875, rows=125054
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat37.625_lon-112.875.csv
#   Dense pixel at lat_gldas=37.625, lon_gldas=-112.625, rows=45545
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat37.625_lon-112.625.csv
#   Dense pixel at lat_gldas=37.875, lon_gldas=-111.875, rows=52574
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat37.875_lon-111.875.csv
#   Dense pixel at lat_gldas=37.875, lon_gldas=-109.375, rows=51465
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat37.875_lon-109.375.csv
#   Dense pixel at lat_gldas=38.125, lon_gldas=-111.375, rows=47280
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat38.125_lon-111.375.csv
#   Dense pixel at lat_gldas=38.375, lon_gldas=-119.625, rows=105148
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat38.375_lon-119.625.csv
#   Dense pixel at lat_gldas=38.375, lon_gldas=-112.375, rows=78861
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat38.375_lon-112.375.csv
#   Dense pixel at lat_gldas=38.375, lon_gldas=-109.375, rows=51475
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat38.375_lon-109.375.csv
#   Dense pixel at lat_gldas=38.625, lon_gldas=-119.875, rows=131435
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat38.625_lon-119.875.csv
#   Dense pixel at lat_gldas=38.625, lon_gldas=-119.625, rows=52574
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat38.625_lon-119.625.csv
#   Dense pixel at lat_gldas=38.875, lon_gldas=-120.125, rows=78861
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat38.875_lon-120.125.csv
# ...
#   Dense pixel at lat_gldas=41.375, lon_gldas=-111.875, rows=77673
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat41.375_lon-111.875.csv
#   Dense pixel at lat_gldas=41.375, lon_gldas=-111.375, rows=78861
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat41.375_lon-111.375.csv
#   Dense pixel at lat_gldas=41.625, lon_gldas=-117.625, rows=52574
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat41.625_lon-117.625.csv
#   Dense pixel at lat_gldas=41.625, lon_gldas=-116.125, rows=52574
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat41.625_lon-116.125.csv
#   Dense pixel at lat_gldas=41.625, lon_gldas=-115.375, rows=52574
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat41.625_lon-115.375.csv
#   Dense pixel at lat_gldas=41.875, lon_gldas=-116.125, rows=52574
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat41.875_lon-116.125.csv
#   Dense pixel at lat_gldas=41.875, lon_gldas=-115.125, rows=29496
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat41.875_lon-115.125.csv
#   Dense pixel at lat_gldas=41.875, lon_gldas=-111.625, rows=131435
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat41.875_lon-111.625.csv
#   Dense pixel at lat_gldas=42.625, lon_gldas=-109.375, rows=52574
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat42.625_lon-109.375.csv
#   Dense pixel at lat_gldas=43.625, lon_gldas=-113.875, rows=59239
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat43.625_lon-113.875.csv
#   Dense pixel at lat_gldas=44.125, lon_gldas=-110.625, rows=52574
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat44.125_lon-110.625.csv
#   Dense pixel at lat_gldas=47.875, lon_gldas=-117.125, rows=52574
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SNOTEL/dense/SNOTEL_dense_lat47.875_lon-117.125.csv
# Stations that appear in dense pixels: 171
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 201 station CSV files (excluding 171 dense stations).
# All done for SNOTEL.
# ===== SUMMARY =====
# Dense pixels processed (with valid data): 64
# Dense pixel files written: 64
#
# === Network: SOILSCAPE ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/SOILSCAPE
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SOILSCAPE
# Found 1 station directories.
#   Skipping SOILSCAPE/node401 (failed filter in summary).
# No valid CSV files found under /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/SOILSCAPE/* (after filtering), skipping.
#
# === Network: STEMS ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/STEMS
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/STEMS
# Found 4 station directories.
# Loaded 4 stations after filtering, total rows: 59292
# Total unique pixels: 1
# Dense pixels (n_stations >= 2): 1
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 59292
#   Dense pixel at lat_gldas=44.625, lon_gldas=8.625, rows=59292
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/STEMS/dense/STEMS_dense_lat44.625_lon8.625.csv
# Stations that appear in dense pixels: 4
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 0 station CSV files (excluding 4 dense stations).
# All done for STEMS.
# ===== SUMMARY =====
# Stations found (raw): 4
# Dense pixels processed (with valid data): 1
# Dense pixel files written: 1
#
# === Network: SWEX_POLAND ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/SWEX_POLAND
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/SWEX_POLAND
# Found 1 station directories.
# Loaded 1 stations after filtering, total rows: 3933
# Total unique pixels: 1
# Dense pixels (n_stations >= 2): 0
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 0
# No dense pixels found to process.
# Stations that appear in dense pixels: 0
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 1 station CSV files (excluding 0 dense stations).
# All done for SWEX_POLAND.
# ===== SUMMARY =====
# Stations found (raw): 1
# Dense pixels processed (with valid data): 0
# Dense pixel files written: 0
#
# === Network: TAHMO ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/TAHMO
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/TAHMO
# Found 29 station directories.
#   Skipping TAHMO/ImurtottPrimaryschool (failed filter in summary).
#   Skipping TAHMO/MagomanoSecondarySchool (failed filter in summary).
#   Skipping TAHMO/MaraTriangleAirstrip (failed filter in summary).
#   Skipping TAHMO/MurungaruSecondarySchool (failed filter in summary).
#   Skipping TAHMO/NaboishoCamp (failed filter in summary).
#   Skipping TAHMO/StJohnsNyamagwa (failed filter in summary).
# Loaded 23 stations after filtering, total rows: 77945
# Total unique pixels: 23
# Dense pixels (n_stations >= 2): 0
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 0
# No dense pixels found to process.
# Stations that appear in dense pixels: 0
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 23 station CSV files (excluding 0 dense stations).
# All done for TAHMO.
# ===== SUMMARY =====
# Stations found (raw): 29
# Dense pixels processed (with valid data): 0
# Dense pixel files written: 0
#
# === Network: TERENO ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/TERENO
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/TERENO
# Found 5 station directories.
# Loaded 5 stations after filtering, total rows: 125557
# Total unique pixels: 3
# Dense pixels (n_stations >= 2): 1
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 75023
#   Dense pixel at lat_gldas=50.875, lon_gldas=6.375, rows=75023
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/TERENO/dense/TERENO_dense_lat50.875_lon6.375.csv
# Stations that appear in dense pixels: 3
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 2 station CSV files (excluding 3 dense stations).
# All done for TERENO.
# ===== SUMMARY =====
# Stations found (raw): 5
# Dense pixels processed (with valid data): 1
# Dense pixel files written: 1
#
# === Network: TWENTE ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/TWENTE
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/TWENTE
# Found 36 station directories.
# Loaded 36 stations after filtering, total rows: 489406
# Total unique pixels: 6
# Dense pixels (n_stations >= 2): 5
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 463119
#   Dense pixel at lat_gldas=52.125, lon_gldas=6.375, rows=52573
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/TWENTE/dense/TWENTE_dense_lat52.125_lon6.375.csv
#   Dense pixel at lat_gldas=52.125, lon_gldas=6.625, rows=99630
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/TWENTE/dense/TWENTE_dense_lat52.125_lon6.625.csv
#   Dense pixel at lat_gldas=52.375, lon_gldas=6.375, rows=57607
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/TWENTE/dense/TWENTE_dense_lat52.375_lon6.375.csv
#   Dense pixel at lat_gldas=52.375, lon_gldas=6.625, rows=113595
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/TWENTE/dense/TWENTE_dense_lat52.375_lon6.625.csv
#   Dense pixel at lat_gldas=52.375, lon_gldas=6.875, rows=139714
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/TWENTE/dense/TWENTE_dense_lat52.375_lon6.875.csv
# Stations that appear in dense pixels: 35
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 1 station CSV files (excluding 35 dense stations).
# All done for TWENTE.
# ===== SUMMARY =====
# Stations found (raw): 36
# Dense pixels processed (with valid data): 5
# Dense pixel files written: 5
#
# === Network: TxSON ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/TxSON
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/TxSON
# Found 40 station directories.
#   Skipping TxSON/CR200-11 (failed filter in summary).
# Loaded 39 stations after filtering, total rows: 696671
# Total unique pixels: 4
# Dense pixels (n_stations >= 2): 4
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 696671
#   Dense pixel at lat_gldas=30.125, lon_gldas=-98.875, rows=53842
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/TxSON/dense/TxSON_dense_lat30.125_lon-98.875.csv
#   Dense pixel at lat_gldas=30.125, lon_gldas=-98.625, rows=141381
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/TxSON/dense/TxSON_dense_lat30.125_lon-98.625.csv
#   Dense pixel at lat_gldas=30.375, lon_gldas=-98.875, rows=321102
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/TxSON/dense/TxSON_dense_lat30.375_lon-98.875.csv
#   Dense pixel at lat_gldas=30.375, lon_gldas=-98.625, rows=180346
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/TxSON/dense/TxSON_dense_lat30.375_lon-98.625.csv
# Stations that appear in dense pixels: 39
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 0 station CSV files (excluding 39 dense stations).
# All done for TxSON.
# ===== SUMMARY =====
# Stations found (raw): 40
# Dense pixels processed (with valid data): 4
# Dense pixel files written: 4
#
# === Network: USCRN ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/USCRN
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/USCRN
# Found 115 station directories.
#   Skipping USCRN/Bodega-6-WSW (failed filter in summary).
#   Skipping USCRN/Brunswick-23-S (failed filter in summary).
#   Skipping USCRN/Coos-Bay-8-SW (failed filter in summary).
#   Skipping USCRN/Santa-Barbara-11-W (failed filter in summary).
#   Skipping USCRN/Titusville-7-E (failed filter in summary).
# Loaded 110 stations after filtering, total rows: 2842769
# Total unique pixels: 104
# Dense pixels (n_stations >= 2): 6
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 313546
#   Dense pixel at lat_gldas=35.375, lon_gldas=-82.625, rows=52574
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/USCRN/dense/USCRN_dense_lat35.375_lon-82.625.csv
#   Dense pixel at lat_gldas=36.125, lon_gldas=-97.125, rows=52574
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/USCRN/dense/USCRN_dense_lat36.125_lon-97.125.csv
#   Dense pixel at lat_gldas=36.625, lon_gldas=-101.625, rows=50676
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/USCRN/dense/USCRN_dense_lat36.625_lon-101.625.csv
#   Dense pixel at lat_gldas=41.375, lon_gldas=-71.625, rows=52574
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/USCRN/dense/USCRN_dense_lat41.375_lon-71.625.csv
#   Dense pixel at lat_gldas=43.125, lon_gldas=-70.875, rows=52574
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/USCRN/dense/USCRN_dense_lat43.125_lon-70.875.csv
#   Dense pixel at lat_gldas=48.375, lon_gldas=-105.125, rows=52574
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/USCRN/dense/USCRN_dense_lat48.375_lon-105.125.csv
# Stations that appear in dense pixels: 12
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 98 station CSV files (excluding 12 dense stations).
# All done for USCRN.
# ===== SUMMARY =====
# Stations found (raw): 115
# Dense pixels processed (with valid data): 6
# Dense pixel files written: 6
#
# === Network: WSMN ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/WSMN
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/WSMN
# Found 7 station directories.
#   Skipping WSMN/WSMN-1 (failed filter in summary).
#   Skipping WSMN/WSMN-2 (failed filter in summary).
#   Skipping WSMN/WSMN-3 (failed filter in summary).
#   Skipping WSMN/WSMN-4 (failed filter in summary).
#   Skipping WSMN/WSMN-5 (failed filter in summary).
#   Skipping WSMN/WSMN-6 (failed filter in summary).
# Loaded 1 stations after filtering, total rows: 5025
# Total unique pixels: 1
# Dense pixels (n_stations >= 2): 0
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 0
# No dense pixels found to process.
# Stations that appear in dense pixels: 0
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 1 station CSV files (excluding 0 dense stations).
# All done for WSMN.
# ===== SUMMARY =====
# Stations found (raw): 7
# Dense pixels processed (with valid data): 0
# Dense pixel files written: 0
#
# === Network: XMS-CAT ===
# Input:  /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/combine/XMS-CAT
# Output: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/XMS-CAT
# Found 8 station directories.
# Loaded 8 stations after filtering, total rows: 72450
# Total unique pixels: 4
# Dense pixels (n_stations >= 2): 2
# Processing dense pixels (pixel-mean files)...
# Rows in dense pixels (before grouping): 54181
#   Dense pixel at lat_gldas=42.125, lon_gldas=0.875, rows=37845
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/XMS-CAT/dense/XMS-CAT_dense_lat42.125_lon0.875.csv
#   Dense pixel at lat_gldas=42.125, lon_gldas=1.125, rows=16336
#     Saved dense pixel file: /home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean/XMS-CAT/dense/XMS-CAT_dense_lat42.125_lon1.125.csv
# Stations that appear in dense pixels: 6
# Writing sparse (station-wise) files (excluding dense stations)...
# Finished sparse files. Processed 2 station CSV files (excluding 6 dense stations).
# All done for XMS-CAT.
# ===== SUMMARY =====
# Stations found (raw): 8
# Dense pixels processed (with valid data): 2
# Dense pixel files written: 2

# %% [markdown]
# ## Checking pixel mean

# %%
import os
import glob
import pandas as pd
from collections import defaultdict

# ---------------------------------------------------------------------
# Paths (GLDAS NOAH)
# ---------------------------------------------------------------------

SUMMARY_PATH = "/home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/gldas_noah_insitu_sd_corr_summary.csv"
PIXEL_MEAN_ROOT = "/home/aminr/Desktop/Master_Thesis/Global_scale/surface_layer/gldas_noah/pixel_mean"

# ---------------------------------------------------------------------
# 1. Load station list from summary
# ---------------------------------------------------------------------

summary_df = pd.read_csv(SUMMARY_PATH)

summary_ok = summary_df[
    (summary_df["pass_sd_filter"] == True) &
    (summary_df["pass_corr_filter"] == True)
]

summary_stations = set(zip(summary_ok["network"], summary_ok["station"]))

print(f"Total stations in summary (passed filters): {len(summary_stations)}")

# ---------------------------------------------------------------------
# 2. Collect stations appearing in dense and sparse
# ---------------------------------------------------------------------

stations_in_dense = set()
stations_in_sparse = set()

network_dirs = sorted(
    d for d in glob.glob(os.path.join(PIXEL_MEAN_ROOT, "*"))
    if os.path.isdir(d)
)
networks = [os.path.basename(d) for d in network_dirs]
print("Networks found in pixel_mean:", networks)

for network in networks:
    base_net  = os.path.join(PIXEL_MEAN_ROOT, network)
    dense_dir = os.path.join(base_net, "dense")
    sparse_dir = os.path.join(base_net, "sparse")

    # ---- Dense: station list from "stations" column ----
    if os.path.exists(dense_dir):
        dense_files = glob.glob(os.path.join(dense_dir, "*.csv"))
        for f in dense_files:
            try:
                df = pd.read_csv(f, usecols=["stations"])
            except Exception as e:
                print(f"[WARN] Could not read stations from dense file {f}: {e}")
                continue

            if df.empty or "stations" not in df.columns:
                continue

            stations_str = str(df["stations"].iloc[0])
            if not stations_str or stations_str.lower() == "nan":
                continue

            for st in stations_str.split(","):
                st = st.strip()
                if st:
                    stations_in_dense.add((network, st))

    # ---- Sparse: infer station from filename ----
    if os.path.exists(sparse_dir):
        sparse_files = glob.glob(os.path.join(sparse_dir, "*.csv"))
        for f in sparse_files:
            fname = os.path.basename(f)
            # Strip .csv
            name_no_ext = fname[:-4] if fname.endswith(".csv") else fname

            # Remove "<network>_" prefix if present
            prefix = network + "_"
            if name_no_ext.startswith(prefix):
                # Example:
                #   network = "CTP_SMTMN"
                #   name_no_ext = "CTP_SMTMN_L35_insitu_gldas_soil_temperature"
                #   tail = "L35_insitu_gldas_soil_temperature"
                tail = name_no_ext[len(prefix):]
            else:
                # If pattern is different, just use the full name_no_ext
                tail = name_no_ext

            # Station is the first token before the next underscore (before "_insitu")
            # e.g. "L35_insitu_gldas_soil_temperature" -> "L35"
            station_from_file = tail.split("_")[0]

            stations_in_sparse.add((network, station_from_file))

# ---------------------------------------------------------------------
# 3. Compute coverage and missing stations
# ---------------------------------------------------------------------

only_dense = summary_stations & stations_in_dense - stations_in_sparse
only_sparse = summary_stations & stations_in_sparse - stations_in_dense
both = summary_stations & stations_in_dense & stations_in_sparse
missing = summary_stations - stations_in_dense - stations_in_sparse

print("\n===== OVERALL STATION COVERAGE =====")
print(f"Stations only in dense:   {len(only_dense)}")
print(f"Stations only in sparse:  {len(only_sparse)}")
print(f"Stations in both:         {len(both)}")
print(f"Stations missing (neither dense nor sparse): {len(missing)}")

# Optional: per-network breakdown
per_network_counts = defaultdict(lambda: {"only_dense": 0, "only_sparse": 0, "both": 0, "missing": 0})

for net, st in only_dense:
    per_network_counts[net]["only_dense"] += 1
for net, st in only_sparse:
    per_network_counts[net]["only_sparse"] += 1
for net, st in both:
    per_network_counts[net]["both"] += 1
for net, st in missing:
    per_network_counts[net]["missing"] += 1

print("\n===== PER-NETWORK SUMMARY =====")
for net in sorted(per_network_counts.keys()):
    c = per_network_counts[net]
    print(
        f"{net}: "
        f"only_dense={c['only_dense']}, "
        f"only_sparse={c['only_sparse']}, "
        f"both={c['both']}, "
        f"missing={c['missing']}"
    )

# ---------------------------------------------------------------------
# 4. Print and save missing stations explicitly
# ---------------------------------------------------------------------

print("\n===== MISSING STATIONS (in summary but not in dense or sparse) =====")
print(f"Total missing: {len(missing)}\n")

for net, st in sorted(missing):
    print(f"{net},{st}")

if missing:
    missing_df = pd.DataFrame(sorted(missing), columns=["network", "station"])
    out_csv = "/home/aminr/Desktop/Master_Thesis/Global_scale/sub_surface_layers/gldas_noah/missing_stations_gldas.csv"
    missing_df.to_csv(out_csv, index=False)
    print(f"\nSaved missing stations to {out_csv}")
# Out:
# Total stations in summary (passed filters): 1274
# Networks found in pixel_mean: ['ARM', 'BIEBRZA_S-1', 'BNZ-LTER', 'Berlin', 'COSMOS-UK', 'CTP_SMTMN', 'CW3E', 'DAHRA', 'FLUXNET-AMERIFLUX', 'FMI', 'FR_Aqui', 'HOAL', 'HOBE', 'HYDROL-NET_PERUGIA', 'IMA_CAN1', 'IPE', 'LAB-net', 'LABFLUX', 'MAQU', 'MOL-RAO', 'MySMNet', 'NAQU', 'NGARI', 'OZNET', 'REMEDHUS', 'RISMA', 'ROMPS', 'RSMN', 'Ru_CFR', 'SCAN', 'SKKU', 'SMN-SDR', 'SMOSMANIA', 'SNOTEL', 'SOILSCAPE', 'STEMS', 'SWEX_POLAND', 'TAHMO', 'TERENO', 'TWENTE', 'TxSON', 'USCRN', 'WSMN', 'XMS-CAT']
#
# ===== OVERALL STATION COVERAGE =====
# Stations only in dense:   600
# Stations only in sparse:  674
# Stations in both:         0
# Stations missing (neither dense nor sparse): 0
#
# ===== PER-NETWORK SUMMARY =====
# ARM: only_dense=0, only_sparse=16, both=0, missing=0
# BIEBRZA_S-1: only_dense=18, only_sparse=0, both=0, missing=0
# BNZ-LTER: only_dense=9, only_sparse=1, both=0, missing=0
# Berlin: only_dense=0, only_sparse=1, both=0, missing=0
# COSMOS-UK: only_dense=2, only_sparse=47, both=0, missing=0
# CTP_SMTMN: only_dense=56, only_sparse=1, both=0, missing=0
# CW3E: only_dense=6, only_sparse=2, both=0, missing=0
# DAHRA: only_dense=0, only_sparse=1, both=0, missing=0
# FLUXNET-AMERIFLUX: only_dense=5, only_sparse=2, both=0, missing=0
# FMI: only_dense=24, only_sparse=1, both=0, missing=0
# FR_Aqui: only_dense=3, only_sparse=2, both=0, missing=0
# HOAL: only_dense=31, only_sparse=0, both=0, missing=0
# HOBE: only_dense=29, only_sparse=1, both=0, missing=0
# HYDROL-NET_PERUGIA: only_dense=0, only_sparse=1, both=0, missing=0
# IMA_CAN1: only_dense=12, only_sparse=0, both=0, missing=0
# IPE: only_dense=0, only_sparse=1, both=0, missing=0
# LAB-net: only_dense=0, only_sparse=3, both=0, missing=0
# LABFLUX: only_dense=0, only_sparse=1, both=0, missing=0
# MAQU: only_dense=16, only_sparse=5, both=0, missing=0
# MOL-RAO: only_dense=0, only_sparse=2, both=0, missing=0
# MySMNet: only_dense=3, only_sparse=0, both=0, missing=0
# NAQU: only_dense=8, only_sparse=2, both=0, missing=0
# NGARI: only_dense=19, only_sparse=1, both=0, missing=0
# OZNET: only_dense=10, only_sparse=7, both=0, missing=0
# REMEDHUS: only_dense=19, only_sparse=1, both=0, missing=0
# RISMA: only_dense=18, only_sparse=5, both=0, missing=0
# ROMPS: only_dense=0, only_sparse=5, both=0, missing=0
# RSMN: only_dense=0, only_sparse=20, both=0, missing=0
# Ru_CFR: only_dense=2, only_sparse=0, both=0, missing=0
# SCAN: only_dense=11, only_sparse=189, both=0, missing=0
# SKKU: only_dense=0, only_sparse=1, both=0, missing=0
# SMN-SDR: only_dense=24, only_sparse=9, both=0, missing=0
# SMOSMANIA: only_dense=5, only_sparse=17, both=0, missing=0
# SNOTEL: only_dense=171, only_sparse=201, both=0, missing=0
# STEMS: only_dense=4, only_sparse=0, both=0, missing=0
# SWEX_POLAND: only_dense=0, only_sparse=1, both=0, missing=0
# TAHMO: only_dense=0, only_sparse=23, both=0, missing=0
# TERENO: only_dense=3, only_sparse=2, both=0, missing=0
# TWENTE: only_dense=35, only_sparse=1, both=0, missing=0
# TxSON: only_dense=39, only_sparse=0, both=0, missing=0
# USCRN: only_dense=12, only_sparse=98, both=0, missing=0
# WSMN: only_dense=0, only_sparse=1, both=0, missing=0
# XMS-CAT: only_dense=6, only_sparse=2, both=0, missing=0
#
# ===== MISSING STATIONS (in summary but not in dense or sparse) =====
# Total missing: 0
